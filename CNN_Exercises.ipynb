# %% [markdown]
# <a href="https://colab.research.google.com/github/jessamcs/Week11_DeepLearning/blob/main/CNN_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Run the network. What do you notice?
# - Output shows test loss is 0.503 and training loss is 0.498. It started with high errors and later on , there's no changes on training loss. It means that the dataset shows it wasn't train accurately.

# %% [markdown]
# 2. Now, increase the number of neurons in the hidden layer and try changing the activation function to something other than "Linear." Can you model the data now? How many neurons and what activation function allows you to effectively model the data?
# - I put 2 neurons on 1 hidden layer and set activation "ReLU". Output shows that the dataset has been train mith minimal errors.

# %% [markdown]
# ![Screenshot 2022-02-02 223431.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 3. Feel free to add more neurons, layers, or change anything you would like - can you model the data so that the testing loss is 0.01 or less? What is the smallest number of neurons and layers you can use that gives a test loss of 0.01 or less?
# - I set the tensor flow with ReLU, 2 Hidden Layers and 5 Neurons. It started with high errors as well but slowly reach 0.001 test loss. The image below shows that the dataset has been train and more accurate than the previous two tensor play.

# %% [markdown]
# ![Screenshot 2022-02-02 235507.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 4. Play around with the learning rate. What do you notice? Based on this, what do you think the learning rate is?
# - Learning rate is hyperparemeter that controls the changes in a model in response with each error time the model weights are updated.
